# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris

# %%
housing = pd.read_csv("/content/housing.csv")
housing
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
#Perform the describe and info steps
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
#Perform the describe and info steps
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
#Plot the histogram of each feature
hist = housing.hist(bins = 15,figsize=(20,15))
hist
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
#Demonstrate the process of creating a test set(
train_set,test_set = train_test_split(housing,random_state=42,test_size=0.2)
print(train_set)
print("------------------------------------------------------------------------")
print(test_set)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14196    -117.03     32.71                33.0       3126.0           627.0
# 8267     -118.16     33.77                49.0       3382.0           787.0
# 17445    -120.48     34.66                 4.0       1897.0           331.0
# 14265    -117.11     32.69                36.0       1421.0           367.0
# 2271     -119.80     36.78                43.0       2382.0           431.0
# ...          ...       ...                 ...          ...             ...
# 11284    -117.96     33.78                35.0       1330.0           201.0
# 11964    -117.43     34.02                33.0       3084.0           570.0
# 5390     -118.38     34.03                36.0       2101.0           569.0
# 860      -121.96     37.58                15.0       3575.0           597.0
# 15795    -122.42     37.77                52.0       4226.0          1315.0
#
# ...

# %%
#stratified sampling
x_strat_train,x_start_test = train_test_split(housing["median_house_value"],test_size = 0.2,random_state = None,stratify =housing["median_house_value"])
print(x_strat_train,"\n---------------------------\n",x_start_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-205452c85a1e> in <cell line: 0>()
#       1 #stratified sampling
# ----> 2 x_strat_train,x_start_test = train_test_split(housing["median_house_value"],test_size = 0.2,random_state = None,stratify =housing["median_house_value"])
#       3 print(x_strat_train,"\n---------------------------\n",x_start_test)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     214                     )
#     215                 ):
# --> 216                     return func(*args, **kwargs)
#     217             except InvalidParameterError as e:
#     218                 # When the function is just a wrapper around an estimator, we allow
#
# ...

# %%
#Demonstrate the process of creating a test set
print(train_set.shape)
print(test_set.shape)
# Out:
# (16512, 10)
# (4128, 10)

# %%
#List the geographical features from the dataset and plot a graph to Visualize Geographical
#latitude, longitude
import matplotlib.pyplot as plt
train_set,test_set = train_test_split(housing,test_size = 0.2,random_state = 42)
train_set.plot(kind = "scatter",x="longitude",y="latitude")
plt.legend()
# Out:
# <ipython-input-36-98b48df8725c>:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#List the geographical features from the dataset and plot a graph to Visualize Geographical
#latitude, longitude
train_set.plot(kind="scatter", x="longitude", y="latitude",
               alpha=0.4, s=train_set["population"]/100, label="population",
               figsize=(10,7), c="median_house_value", cmap=plt.get_cmap("jet"),
               colorbar=True)
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
#Plot a graph to show features correlation with housing price.
#Which feature corelates to the maximum. Plot the graph for that
#with housing price and analyze what the graph indicate
numerical_columns = housing.select_dtypes(include=['float64','int64'])
correlation_matrix = numerical_columns.corr()
print(correlation_matrix["median_house_value"].sort_values(ascending=True))
# Out:
# latitude             -0.144160
# longitude            -0.045967
# population           -0.024650
# total_bedrooms        0.049686
# households            0.065843
# housing_median_age    0.105623
# total_rooms           0.134153
# median_income         0.688075
# median_house_value    1.000000
# Name: median_house_value, dtype: float64

# %%
#Plot the graph for that with housing price and analyze what the graph indicate
housing.plot(kind="scatter", x="median_income",
             y="median_house_value", alpha=0.1)
# Out:
# <Axes: xlabel='median_income', ylabel='median_house_value'>

# %%
housing.plot(kind="scatter", x="median_income",
             y="housing_median_age", alpha=0.1)
# Out:
# <Axes: xlabel='median_income', ylabel='housing_median_age'>

# %%
housing.plot(kind="scatter", x="median_income",
             y="total_rooms", alpha=0.1)
# Out:
# <Axes: xlabel='median_income', ylabel='total_rooms'>

# %%
housing.plot(kind="scatter", x="median_income",
             y="total_bedrooms", alpha=0.1)
# Out:
# <Axes: xlabel='median_income', ylabel='total_bedrooms'>

# %%
housing.plot(kind="scatter", x="median_income",
             y="population", alpha=0.1)
# Out:
# <Axes: xlabel='median_income', ylabel='population'>

# %%
housing.plot(kind="scatter", x="median_income",
             y="households", alpha=0.1)
# Out:
# <Axes: xlabel='median_income', ylabel='households'>

# %%
housing.plot(kind="scatter", x="median_income",
             y="median_income", alpha=0.1)
# Out:
# <Axes: xlabel='median_income', ylabel='median_income'>

# %%
housing.plot(kind="scatter", x="median_income",
             y="median_house_value", alpha=0.1)
# Out:
# <Axes: xlabel='median_income', ylabel='median_house_value'>

# %%
#population and housholds can be combined
#total bedrooms and total_rooms can be combined

# %%
#total_bedrooms need to be cleaned, as it hassoem missing values

# %%
#Is there any categorical data that needs to be converted to
#numerical? If so explain the method used to convert and code the
#same and show the output.

#yes it is ocean_proximity

# %%
#discuss importance of feature scalling

# %%
#Design a pipeline inculcating (Custom transform, feature
#scaling and encoding). Explain how it works
